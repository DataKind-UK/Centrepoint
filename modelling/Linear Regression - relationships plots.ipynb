# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ### Read in the data

# %%
census_colname = 'ONS_Census_2011'
TARGET_COLNAME = 'TOTAL_Presented_Young_ppl_2014'
target_colname = '{0}'.format(TARGET_COLNAME)
population_colname = 'LA_Population_young'
population_total_colname = 'LA_Population'

# %%
DATA_RAW = pd.read_csv('../source data/new data/CP ETL output.csv')
mask = ((DATA_RAW[census_colname].str[0] == 'E') + (DATA_RAW[census_colname].str[0] == 'W'))
DATA_ENG_WAL_RAW = DATA_RAW[mask]
DATA_ENG_WAL = DATA_ENG_WAL_RAW[DATA_ENG_WAL_RAW[census_colname].notnull()]

# "test" subset — all records with known ONS codes
data_eng = DATA_ENG_WAL.copy()
#kick out the outlier: Milton Keynes
data_eng = data_eng[data_eng[census_colname] != 'E06000042']
# Out:
# /home/adam/anaconda3/lib/python3.4/site-packages/pandas/computation/expressions.py:190: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   unsupported[op_str]))

# %% [markdown]
# Use young population as a predictor, not the total population:

# %%
YOUNG_POPULATION = pd.read_csv('../source data/new data/young_populations.csv')
data_eng = data_eng.merge(YOUNG_POPULATION, how='left', on=census_colname)

# %% [markdown]
# ### Tidy up
#
# I don't like punctuation in column names. Also they shouldn't start with a number

# %%
to_replace = (':', '/', ';', ',', '(', ')')

for col in data_eng.columns:
    if col not in [population_colname, census_colname]:
        newname = col
        if newname[0].isdigit():
            newname = 'p_{0}'.format(newname)
        newname = newname.replace(' ', '_')
        for item in to_replace:
            newname = newname.replace(item, '')

        data_eng = data_eng.rename(columns={col: newname})

#I don't like this very long variable name, I'll rename it:
data_eng = data_eng.rename(columns={'All_persons_Highest_Level_of_Qualification_All_categories_Highest_level_of_qualification_measures_Value_Total': 'edu_highest'})

# %%
#For printing all columns:
#data_eng.columns

# %% [markdown]
# Define relevant columns (done by hand):

# %%
target_columns = ['TOTAL_Presented_Young_ppl_2014', 'TOTAL_Assessed_Young_ppl_2014']
unempl_columns = ['unemployed_age_16_and_over', 'unemployment_age_16_to_24', 'unemployment_age_25_to_34', 'never_worked_age_16_and_over', 'never_worked_age_16_to_24', 'never_worked_age_25_to_34']
ethno_columns = ['All_categories_Ethnic_group_of_HRP', 'White_Total', 'White_EnglishWelshScottishNorthern_IrishBritish', 'White_Irish', 'White_Gypsy_or_Irish_Traveller', 'White_Other_White', 'Mixedmultiple_ethnic_group_Total', 'Mixedmultiple_ethnic_group_White_and_Black_Caribbean', 'Mixedmultiple_ethnic_group_White_and_Black_African', 'Mixedmultiple_ethnic_group_White_and_Asian', 'Mixedmultiple_ethnic_group_Other_Mixed', 'AsianAsian_British_Total', 'AsianAsian_British_Indian', 'AsianAsian_British_Pakistani', 'AsianAsian_British_Bangladeshi', 'AsianAsian_British_Chinese', 'AsianAsian_British_Other_Asian', 'BlackAfricanCaribbeanBlack_British_Total', 'BlackAfricanCaribbeanBlack_British_African', 'BlackAfricanCaribbeanBlack_British_Caribbean', 'BlackAfricanCaribbeanBlack_British_Other_Black', 'Other_ethnic_group_Total', 'Other_ethnic_group_Arab', 'Other_ethnic_group_Any_other_ethnic_group']
edu_columns = ['edu_highest', '_All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value', '_All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value', 'All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value', 'All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value', '_All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value', '_All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value', '_All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value']

# %% [markdown]
# All analysis should be done on normalised data, e.g. numbers divided by populations.

# %%
columns_to_normalise = unempl_columns + ethno_columns + edu_columns
columns_to_normalise_young = ['unemployment_age_16_to_24', 'never_worked_age_16_to_24']
columns_all = [x for x in columns_to_normalise if x not in columns_to_normalise_young]
for column in columns_all:
    data_eng[column] = data_eng[column]/data_eng[population_total_colname]
for column in columns_to_normalise_young:
    data_eng[column] = data_eng[column]/data_eng[population_colname]
    
data_eng['Presented_Normalised'] = data_eng[target_colname]/data_eng[population_colname]

# %%
data_eng.head(5)
# Out:
#    Country           County_Name ONS_Census_2011       Local_Authority  \
# 0  England            Hartlepool       E06000001            Hartlepool
# 1  England         Middlesbrough       E06000002         Middlesbrough
# 2  England                 Derby       E06000015                 Derby
# 3  England  Redcar and Cleveland       E06000003  Redcar and Cleveland
# 4  England      Stockton-on-Tees       E06000004      Stockton-on-Tees
#
#    LA_Type  LA_Population  LA_Area_Hec  TOTAL_Presented_Young_ppl_2014  \
# 0  Unitary          92028      9386.11                             NaN
# 1  Unitary         138412      5387.47                             NaN
# 2  Unitary         248752      7803.11                             109
# 3  Unitary         135177     24489.51                             NaN
# 4  Unitary         191610     20393.06                             NaN
#
#    TOTAL_Assessed_Young_ppl_2014  TOTAL_Presented_Young_ppl_2013  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            183                             148
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    TOTAL_Assessed_Young_ppl_2013  TOTAL_Presented_Young_ppl_2012  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            246                              33
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    TOTAL_Assessed_Young_ppl_2012  Missing_Data_Presented_HS_2014  \
# 0                            NaN                               1
# 1                            NaN                               1
# 2                            103                               0
# 3                            NaN                               1
# 4                            NaN                               1
#
#    Missing_Data_Presented_CS_2014  Missing_Data_Assessed_HS_2014  \
# 0                               0                              1
# 1                               0                              1
# 2                               0                              0
# 3                               0                              1
# 4                               0                              1
#
#    Missing_Data_Assessed_CS_2014  Missing_Data_Presented_HS_2013  \
# 0                              0                               1
# 1                              0                               1
# 2                              0                               0
# 3                              0                               1
# 4                              0                               1
#
#    Missing_Data_Presented_CS_2013  Missing_Data_Assessed_HS_2013  \
# 0                               0                              1
# 1                               0                              1
# 2                               0                              0
# 3                               0                              1
# 4                               0                              1
#
#    Missing_Data_Assessed_CS_2013  Missing_Data_Presented_HS_2012  \
# 0                              0                               1
# 1                              0                               1
# 2                              0                               0
# 3                              0                               1
# 4                              0                               1
#
#    Missing_Data_Presented_CS_2012  Missing_Data_Assessed_HS_2012  \
# 0                               0                              1
# 1                               0                              1
# 2                               0                              0
# 3                               0                              1
# 4                               0                              1
#
#    Missing_Data_Assessed_CS_2012  unemployed_age_16_and_over  \
# 0                              0                    0.394815
# 1                              0                    0.402422
# 2                              0                    0.342638
# 3                              0                    0.402568
# 4                              0                    0.350222
#
#    unemployment_age_16_to_24  unemployment_age_25_to_34  \
# 0                   0.569141                   0.034413
# 1                   0.588325                   0.044606
# 2                   0.524650                   0.033314
# 3                   0.538344                   0.027764
# 4                   0.527745                   0.029696
#
#    never_worked_age_16_and_over  never_worked_age_16_to_24  \
# 0                      0.079845                   0.381185
# 1                      0.104630                   0.366802
# 2                      0.074894                   0.303879
# 3                      0.071876                   0.367208
# 4                      0.068384                   0.341931
#
#    never_worked_age_25_to_34  IMD_SCORE  \
# 0                   0.008954      42.83
# 1                   0.015779      13.06
# 2                   0.009475      35.70
# 3                   0.006466       9.80
# 4                   0.007129      17.62
#
#    RANK_OF_IMD_SCORE_where_1_is_most_deprived  \
# 0                                        3747
# 1                                       20324
# 2                                        5977
# 3                                       24278
# 4                                       15923
#
#    All_categories_Ethnic_group_of_HRP  White_Total  \
# 0                            0.439366     0.432010
# 1                            0.413281     0.379469
# 2                            0.411136     0.351161
# 3                            0.440940     0.436539
# 4                            0.413126     0.398205
#
#    White_EnglishWelshScottishNorthern_IrishBritish  White_Irish  \
# 0                                         0.427283     0.001271
# 1                                         0.370676     0.002189
# 2                                         0.330313     0.005624
# 3                                         0.432263     0.001864
# 4                                         0.392991     0.001597
#
#    White_Gypsy_or_Irish_Traveller  White_Other_White  \
# 0                        0.000130           0.003325
# 1                        0.000217           0.006387
# 2                        0.000330           0.014894
# 3                        0.000185           0.002227
# 4                        0.000193           0.003424
#
#    Mixedmultiple_ethnic_group_Total  \
# 0                          0.001826
# 1                          0.004284
# 2                          0.007103
# 3                          0.001531
# 4                          0.001994
#
#    Mixedmultiple_ethnic_group_White_and_Black_Caribbean  \
# 0                                           0.000858
# 1                                           0.001221
# 2                                           0.004012
# 3                                           0.000658
# 4                                           0.000564
#
#    Mixedmultiple_ethnic_group_White_and_Black_African  \
# 0                                           0.000087
# 1                                           0.000708
# 2                                           0.000583
# 3                                           0.000111
# 4                                           0.000282
#
#    Mixedmultiple_ethnic_group_White_and_Asian  \
# 0                                    0.000348
# 1                                    0.001358
# 2                                    0.001439
# 3                                    0.000392
# 4                                    0.000611
#
#    Mixedmultiple_ethnic_group_Other_Mixed  AsianAsian_British_Total  \
# 0                                0.000532                  0.004238
# 1                                0.000997                  0.021335
# 2                                0.001069                  0.034372
# 3                                0.000370                  0.002071
# 4                                0.000538                  0.009879
#
#    AsianAsian_British_Indian  AsianAsian_British_Pakistani  \
# 0                   0.001065                      0.000804
# 1                   0.003352                      0.012145
# 2                   0.013632                      0.013640
# 3                   0.000325                      0.000562
# 4                   0.002542                      0.003972
#
#    AsianAsian_British_Bangladeshi  AsianAsian_British_Chinese  \
# 0                        0.000489                    0.000837
# 1                        0.000520                    0.002305
# 2                        0.000631                    0.001897
# 3                        0.000222                    0.000436
# 4                        0.000172                    0.001378
#
#    AsianAsian_British_Other_Asian  BlackAfricanCaribbeanBlack_British_Total  \
# 0                        0.001043                                  0.000750
# 1                        0.003013                                  0.004292
# 2                        0.004571                                  0.013620
# 3                        0.000525                                  0.000422
# 4                        0.001816                                  0.001858
#
#    BlackAfricanCaribbeanBlack_British_African  \
# 0                                    0.000565
# 1                                    0.003605
# 2                                    0.004748
# 3                                    0.000274
# 4                                    0.001529
#
#    BlackAfricanCaribbeanBlack_British_Caribbean  \
# 0                                      0.000152
# 1                                      0.000361
# 2                                      0.007642
# 3                                      0.000118
# 4                                      0.000193
#
#    BlackAfricanCaribbeanBlack_British_Other_Black  Other_ethnic_group_Total  \
# 0                                        0.000033                  0.000543
# 1                                        0.000325                  0.003901
# 2                                        0.001230                  0.004880
# 3                                        0.000030                  0.000377
# 4                                        0.000136                  0.001190
#
#    Other_ethnic_group_Arab  Other_ethnic_group_Any_other_ethnic_group  \
# 0                 0.000304                                   0.000239
# 1                 0.002312                                   0.001589
# 2                 0.001355                                   0.003526
# 3                 0.000141                                   0.000237
# 4                 0.000449                                   0.000741
#
#    edu_highest  \
# 0     0.806581
# 1     0.797684
# 2     0.796279
# 3     0.821227
# 4     0.806341
#
#    _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value  \
# 0                                           0.247294
# 1                                           0.238433
# 2                                           0.191882
# 3                                           0.233398
# 4                                           0.191681
#
#    _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value  \
# 0                                           0.109282
# 1                                           0.108755
# 2                                           0.105704
# 3                                           0.110574
# 4                                           0.112024
#
#    All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value  \
# 0                                           0.130308
# 1                                           0.122034
# 2                                           0.115300
# 3                                           0.134823
# 4                                           0.135948
#
#    All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value  \
# 0                                           0.044291
# 1                                           0.035214
# 2                                           0.039369
# 3                                           0.047094
# 4                                           0.042195
#
#    _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value  \
# 0                                           0.100795
# 1                                           0.105063
# 2                                           0.103871
# 3                                           0.107799
# 4                                           0.109347
#
#    _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value  \
# 0                                           0.141946
# 1                                           0.147906
# 2                                           0.192782
# 3                                           0.155448
# 4                                           0.183967
#
#    _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value  \
# 0                                           0.032664
# 1                                           0.040278
# 2                                           0.047372
# 3                                           0.032091
# 4                                           0.031178
#
#    LA_Population_young  Presented_Normalised
# 0                10428                   NaN
# 1                19700                   NaN
# 2                32536               0.00335
# 3                14357                   NaN
# 4                22022                   NaN

# %% [markdown]
# ### P1E data
#
# Read them in and merge with the rest.

# %%
p1e = pd.read_csv('../source data/new data/p1e.csv')

p1e_columns = []
for year in (2012, 2013, 2014):
    for i in range(4):
        p1e_columns.append('p_{0}_{1}'.format(year, i+1))
        p1e_columns.append('p_{0}_{1}_all'.format(year, i+1))
        
p1e_columns = p1e_columns[2:]

data_eng = data_eng.merge(p1e[[census_colname] + p1e_columns], on=census_colname, how='left')

#don't normalise for now
#for column in p1e_columns:
#    data_eng[column] = data_eng[column]/data_eng[population_total_colname]

# %% [markdown]
# How many LAs have P1E data for the whole 2014?

# %%
print(len(p1e.dropna(subset=['p_2014_1_all', 'p_2014_2_all', 'p_2014_3_all', 'p_2014_4_all'], how='any')))
print(len(p1e.dropna(subset=['p_2014_3_all'], how='any')))
# Out:
# 260
# 297

# %% [markdown]
# ### Shelter data
#
# If you want, you can import data from Shelter folder. You can then add them to predictor variables with:
# ```python
# for col in to_join:
#     predictors.append(to_join[col][1])
# ```

# %%
test = data_eng.copy()

# the structure of this dictionary is as follows: {filename: [[column_name_in_csv], desired_column_name]}
to_join = {'Average weekly council rents': [['13/14'], 'avg_council_rents'],
           'Council homes sold through Right To Buy': [['13/14'], 'right_to_buy'],
           'Housing Benefit claimants - all': [['housing_benefit'], 'housing_benefit']}

for metric in to_join:
    temp = pd.read_csv('../source data/new data/Shelter_Data/{0}.csv'.format(metric))
    temp = temp[['ONS'] + to_join[metric][0]].dropna().rename(columns={'ONS': census_colname})
    test = test.merge(temp, how='left', on = census_colname)
    
    rename_cols = {to_join[metric][0][0]: to_join[metric][1]}
    test = test.rename(columns=rename_cols)

#which columns should be normalised?
columns_to_normalise_new = ['right_to_buy', 'housing_benefit']
for column in columns_to_normalise_new:
    test[column] = test[column].astype(float)/test[population_total_colname]

# %%
print('Number of LAs with "presented" known:', len(test.dropna(subset=[target_colname])))
print('\nShelter data are full of holes. These are numbers of LAs with respective Shelter columns defined:')
for col in to_join:
    print(len(test.dropna(subset=[to_join[col][1], target_colname])), '\t', col)
# Out:
# Number of LAs with "presented" known: 200
#
# Shelter data are full of holes. These are numbers of LAs with respective Shelter columns defined:
# 95 	 Council homes sold through Right To Buy
# 187 	 Housing Benefit claimants - all
# 87 	 Average weekly council rents

# %% [markdown]
# So we can add "Housing Benefit claimants" from Shelter.
# Define predictors:

# %%
predictors = unempl_columns + ethno_columns + edu_columns + [population_colname]
# only using one column from p1e data (total homeless from 2014.3), the rest is patchy
predictors.append('p_2014_3_all')
predictors.append('IMD_SCORE')
predictors.append('housing_benefit')
#for col in to_join:
#    predictors.append(to_join[col][1])
    
pd.set_option('display.max_columns', None) # show all columns

# make a subset where all predictors and "presented" (target) != NaN
test_filled = test.dropna(subset=predictors, how='any')

# %% [markdown]
# Add the "training" subset, i.e. where we know "presented" numbers.

# %%
train_filled = test_filled[test_filled['Missing_Data_Presented_HS_2014'] == 0]

# %% [markdown]
# Explore cross-correlations:

# %%
train_filled[predictors].corr()
# Out:
#                                                                                              unemployed_age_16_and_over  \
# unemployed_age_16_and_over                                                                                     1.000000
# unemployment_age_16_to_24                                                                                      0.131678
# unemployment_age_25_to_34                                                                                      0.073522
# never_worked_age_16_and_over                                                                                   0.206583
# never_worked_age_16_to_24                                                                                      0.008750
# never_worked_age_25_to_34                                                                                      0.087170
# All_categories_Ethnic_group_of_HRP                                                                             0.199064
# White_Total                                                                                                    0.258579
# White_EnglishWelshScottishNorthern_IrishBritish                                                                0.316526
# White_Irish                                                                                                   -0.363711
# White_Gypsy_or_Irish_Traveller                                                                                -0.128862
# White_Other_White                                                                                             -0.305597
# Mixedmultiple_ethnic_group_Total                                                                              -0.295456
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                          -0.191960
# Mixedmultiple_ethnic_group_White_and_Black_African                                                            -0.299773
# Mixedmultiple_ethnic_group_White_and_Asian                                                                    -0.318136
# Mixedmultiple_ethnic_group_Other_Mixed                                                                        -0.309393
# AsianAsian_British_Total                                                                                      -0.117267
# AsianAsian_British_Indian                                                                                     -0.042618
# AsianAsian_British_Pakistani                                                                                   0.026208
# AsianAsian_British_Bangladeshi                                                                                -0.068048
# AsianAsian_British_Chinese                                                                                    -0.254004
# AsianAsian_British_Other_Asian                                                                                -0.261880
# BlackAfricanCaribbeanBlack_British_Total                                                                      -0.253859
# BlackAfricanCaribbeanBlack_British_African                                                                    -0.256490
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                  -0.235389
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                -0.240435
# Other_ethnic_group_Total                                                                                      -0.155455
# Other_ethnic_group_Arab                                                                                       -0.124564
# Other_ethnic_group_Any_other_ethnic_group                                                                     -0.161683
# edu_highest                                                                                                    0.269966
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                   0.673621
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                              0.266984
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                               0.257824
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                       0.332568
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                              0.163319
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                   -0.464911
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                               -0.166922
# LA_Population_young                                                                                            0.139381
# p_2014_3_all                                                                                                  -0.002893
# IMD_SCORE                                                                                                      0.346962
# housing_benefit                                                                                                0.311330
#
#                                                                                              unemployment_age_16_to_24  \
# unemployed_age_16_and_over                                                                                    0.131678
# unemployment_age_16_to_24                                                                                     1.000000
# unemployment_age_25_to_34                                                                                     0.858755
# never_worked_age_16_and_over                                                                                  0.889626
# never_worked_age_16_to_24                                                                                     0.854682
# never_worked_age_25_to_34                                                                                     0.843058
# All_categories_Ethnic_group_of_HRP                                                                           -0.118781
# White_Total                                                                                                  -0.656651
# White_EnglishWelshScottishNorthern_IrishBritish                                                              -0.749411
# White_Irish                                                                                                   0.676882
# White_Gypsy_or_Irish_Traveller                                                                               -0.156308
# White_Other_White                                                                                             0.650645
# Mixedmultiple_ethnic_group_Total                                                                              0.733899
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                          0.617890
# Mixedmultiple_ethnic_group_White_and_Black_African                                                            0.664436
# Mixedmultiple_ethnic_group_White_and_Asian                                                                    0.734729
# Mixedmultiple_ethnic_group_Other_Mixed                                                                        0.701691
# AsianAsian_British_Total                                                                                      0.733532
# AsianAsian_British_Indian                                                                                     0.536833
# AsianAsian_British_Pakistani                                                                                  0.435449
# AsianAsian_British_Bangladeshi                                                                                0.608505
# AsianAsian_British_Chinese                                                                                    0.647407
# AsianAsian_British_Other_Asian                                                                                0.719162
# BlackAfricanCaribbeanBlack_British_Total                                                                      0.596118
# BlackAfricanCaribbeanBlack_British_African                                                                    0.593424
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                  0.565471
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                0.553095
# Other_ethnic_group_Total                                                                                      0.761060
# Other_ethnic_group_Arab                                                                                       0.697277
# Other_ethnic_group_Any_other_ethnic_group                                                                     0.728877
# edu_highest                                                                                                  -0.169227
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                 -0.126113
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                            -0.510171
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                             -0.750611
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                     -0.672612
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                            -0.096814
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                   0.270943
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                               0.710446
# LA_Population_young                                                                                           0.459687
# p_2014_3_all                                                                                                  0.437877
# IMD_SCORE                                                                                                     0.302631
# housing_benefit                                                                                               0.644214
#
#                                                                                              unemployment_age_25_to_34  \
# unemployed_age_16_and_over                                                                                    0.073522
# unemployment_age_16_to_24                                                                                     0.858755
# unemployment_age_25_to_34                                                                                     1.000000
# never_worked_age_16_and_over                                                                                  0.932326
# never_worked_age_16_to_24                                                                                     0.728238
# never_worked_age_25_to_34                                                                                     0.953985
# All_categories_Ethnic_group_of_HRP                                                                           -0.248640
# White_Total                                                                                                  -0.729376
# White_EnglishWelshScottishNorthern_IrishBritish                                                              -0.767217
# White_Irish                                                                                                   0.601938
# White_Gypsy_or_Irish_Traveller                                                                               -0.130772
# White_Other_White                                                                                             0.538695
# Mixedmultiple_ethnic_group_Total                                                                              0.731191
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                          0.729774
# Mixedmultiple_ethnic_group_White_and_Black_African                                                            0.659839
# Mixedmultiple_ethnic_group_White_and_Asian                                                                    0.652492
# Mixedmultiple_ethnic_group_Other_Mixed                                                                        0.638742
# AsianAsian_British_Total                                                                                      0.730780
# AsianAsian_British_Indian                                                                                     0.522875
# AsianAsian_British_Pakistani                                                                                  0.560320
# AsianAsian_British_Bangladeshi                                                                                0.660825
# AsianAsian_British_Chinese                                                                                    0.513532
# AsianAsian_British_Other_Asian                                                                                0.635717
# BlackAfricanCaribbeanBlack_British_Total                                                                      0.663739
# BlackAfricanCaribbeanBlack_British_African                                                                    0.658970
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                  0.633018
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                0.610591
# Other_ethnic_group_Total                                                                                      0.650796
# Other_ethnic_group_Arab                                                                                       0.538453
# Other_ethnic_group_Any_other_ethnic_group                                                                     0.664702
# edu_highest                                                                                                  -0.385646
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                  0.068547
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                            -0.247662
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                             -0.621685
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                     -0.605037
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                            -0.152327
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                   0.006801
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                               0.727764
# LA_Population_young                                                                                           0.541010
# p_2014_3_all                                                                                                  0.519305
# IMD_SCORE                                                                                                     0.423431
# housing_benefit                                                                                               0.796308
#
#                                                                                              never_worked_age_16_and_over  \
# unemployed_age_16_and_over                                                                                       0.206583
# unemployment_age_16_to_24                                                                                        0.889626
# unemployment_age_25_to_34                                                                                        0.932326
# never_worked_age_16_and_over                                                                                     1.000000
# never_worked_age_16_to_24                                                                                        0.802865
# never_worked_age_25_to_34                                                                                        0.971482
# All_categories_Ethnic_group_of_HRP                                                                              -0.315800
# White_Total                                                                                                     -0.768886
# White_EnglishWelshScottishNorthern_IrishBritish                                                                 -0.778426
# White_Irish                                                                                                      0.563285
# White_Gypsy_or_Irish_Traveller                                                                                  -0.132944
# White_Other_White                                                                                                0.482667
# Mixedmultiple_ethnic_group_Total                                                                                 0.663029
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                             0.649349
# Mixedmultiple_ethnic_group_White_and_Black_African                                                               0.589420
# Mixedmultiple_ethnic_group_White_and_Asian                                                                       0.615418
# Mixedmultiple_ethnic_group_Other_Mixed                                                                           0.578952
# AsianAsian_British_Total                                                                                         0.786359
# AsianAsian_British_Indian                                                                                        0.608737
# AsianAsian_British_Pakistani                                                                                     0.591520
# AsianAsian_British_Bangladeshi                                                                                   0.654235
# AsianAsian_British_Chinese                                                                                       0.472266
# AsianAsian_British_Other_Asian                                                                                   0.651954
# BlackAfricanCaribbeanBlack_British_Total                                                                         0.625158
# BlackAfricanCaribbeanBlack_British_African                                                                       0.610071
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                     0.605598
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                   0.581232
# Other_ethnic_group_Total                                                                                         0.690751
# Other_ethnic_group_Arab                                                                                          0.567049
# Other_ethnic_group_Any_other_ethnic_group                                                                        0.708708
# edu_highest                                                                                                     -0.376596
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                     0.078476
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                               -0.320493
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                                -0.625138
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                        -0.590543
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                               -0.130218
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                      0.024356
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                                  0.693500
# LA_Population_young                                                                                              0.599896
# p_2014_3_all                                                                                                     0.558363
# IMD_SCORE                                                                                                        0.396905
# housing_benefit                                                                                                  0.720347
#
#                                                                                              never_worked_age_16_to_24  \
# unemployed_age_16_and_over                                                                                    0.008750
# unemployment_age_16_to_24                                                                                     0.854682
# unemployment_age_25_to_34                                                                                     0.728238
# never_worked_age_16_and_over                                                                                  0.802865
# never_worked_age_16_to_24                                                                                     1.000000
# never_worked_age_25_to_34                                                                                     0.774684
# All_categories_Ethnic_group_of_HRP                                                                           -0.116031
# White_Total                                                                                                  -0.645328
# White_EnglishWelshScottishNorthern_IrishBritish                                                              -0.741209
# White_Irish                                                                                                   0.681468
# White_Gypsy_or_Irish_Traveller                                                                               -0.096620
# White_Other_White                                                                                             0.650993
# Mixedmultiple_ethnic_group_Total                                                                              0.696398
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                          0.536069
# Mixedmultiple_ethnic_group_White_and_Black_African                                                            0.648806
# Mixedmultiple_ethnic_group_White_and_Asian                                                                    0.724860
# Mixedmultiple_ethnic_group_Other_Mixed                                                                        0.688936
# AsianAsian_British_Total                                                                                      0.708029
# AsianAsian_British_Indian                                                                                     0.488304
# AsianAsian_British_Pakistani                                                                                  0.443603
# AsianAsian_British_Bangladeshi                                                                                0.593206
# AsianAsian_British_Chinese                                                                                    0.600164
# AsianAsian_British_Other_Asian                                                                                0.741167
# BlackAfricanCaribbeanBlack_British_Total                                                                      0.601618
# BlackAfricanCaribbeanBlack_British_African                                                                    0.590355
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                  0.578816
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                0.561203
# Other_ethnic_group_Total                                                                                      0.770362
# Other_ethnic_group_Arab                                                                                       0.675515
# Other_ethnic_group_Any_other_ethnic_group                                                                     0.759491
# edu_highest                                                                                                  -0.303372
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                 -0.129796
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                            -0.450123
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                             -0.658219
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                     -0.670949
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                            -0.488977
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                   0.266496
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                               0.701788
# LA_Population_young                                                                                           0.312139
# p_2014_3_all                                                                                                  0.407763
# IMD_SCORE                                                                                                     0.197944
# housing_benefit                                                                                               0.541049
#
#                                                                                              never_worked_age_25_to_34  \
# unemployed_age_16_and_over                                                                                    0.087170
# unemployment_age_16_to_24                                                                                     0.843058
# unemployment_age_25_to_34                                                                                     0.953985
# never_worked_age_16_and_over                                                                                  0.971482
# never_worked_age_16_to_24                                                                                     0.774684
# never_worked_age_25_to_34                                                                                     1.000000
# All_categories_Ethnic_group_of_HRP                                                                           -0.328310
# White_Total                                                                                                  -0.806876
# White_EnglishWelshScottishNorthern_IrishBritish                                                              -0.817804
# White_Irish                                                                                                   0.603255
# White_Gypsy_or_Irish_Traveller                                                                               -0.126672
# White_Other_White                                                                                             0.507189
# Mixedmultiple_ethnic_group_Total                                                                              0.709181
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                          0.706681
# Mixedmultiple_ethnic_group_White_and_Black_African                                                            0.630302
# Mixedmultiple_ethnic_group_White_and_Asian                                                                    0.652459
# Mixedmultiple_ethnic_group_Other_Mixed                                                                        0.610763
# AsianAsian_British_Total                                                                                      0.811080
# AsianAsian_British_Indian                                                                                     0.590179
# AsianAsian_British_Pakistani                                                                                  0.664321
# AsianAsian_British_Bangladeshi                                                                                0.694102
# AsianAsian_British_Chinese                                                                                    0.481665
# AsianAsian_British_Other_Asian                                                                                0.684492
# BlackAfricanCaribbeanBlack_British_Total                                                                      0.682399
# BlackAfricanCaribbeanBlack_British_African                                                                    0.670146
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                  0.657655
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                0.630864
# Other_ethnic_group_Total                                                                                      0.695718
# Other_ethnic_group_Arab                                                                                       0.559670
# Other_ethnic_group_Any_other_ethnic_group                                                                     0.722016
# edu_highest                                                                                                  -0.430050
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                  0.030081
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                            -0.326871
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                             -0.652275
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                     -0.603083
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                            -0.201101
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                   0.049590
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                               0.734813
# LA_Population_young                                                                                           0.614935
# p_2014_3_all                                                                                                  0.585929
# IMD_SCORE                                                                                                     0.358432
# housing_benefit                                                                                               0.707142
#
#                                                                                              All_categories_Ethnic_group_of_HRP  \
# unemployed_age_16_and_over                                                                                             0.199064
# unemployment_age_16_to_24                                                                                             -0.118781
# unemployment_age_25_to_34                                                                                             -0.248640
# never_worked_age_16_and_over                                                                                          -0.315800
# never_worked_age_16_to_24                                                                                             -0.116031
# never_worked_age_25_to_34                                                                                             -0.328310
# All_categories_Ethnic_group_of_HRP                                                                                     1.000000
# White_Total                                                                                                            0.678118
# White_EnglishWelshScottishNorthern_IrishBritish                                                                        0.468046
# White_Irish                                                                                                           -0.033065
# White_Gypsy_or_Irish_Traveller                                                                                        -0.145883
# White_Other_White                                                                                                      0.199326
# Mixedmultiple_ethnic_group_Total                                                                                      -0.014452
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                                  -0.184436
# Mixedmultiple_ethnic_group_White_and_Black_African                                                                     0.032136
# Mixedmultiple_ethnic_group_White_and_Asian                                                                             0.034781
# Mixedmultiple_ethnic_group_Other_Mixed                                                                                 0.109497
# AsianAsian_British_Total                                                                                              -0.335502
# AsianAsian_British_Indian                                                                                             -0.416275
# AsianAsian_British_Pakistani                                                                                          -0.316347
# AsianAsian_British_Bangladeshi                                                                                        -0.014698
# AsianAsian_British_Chinese                                                                                             0.291305
# AsianAsian_British_Other_Asian                                                                                        -0.167580
# BlackAfricanCaribbeanBlack_British_Total                                                                              -0.203952
# BlackAfricanCaribbeanBlack_British_African                                                                            -0.194351
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                          -0.210929
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                        -0.160878
# Other_ethnic_group_Total                                                                                              -0.047879
# Other_ethnic_group_Arab                                                                                                0.097355
# Other_ethnic_group_Any_other_ethnic_group                                                                             -0.147067
# edu_highest                                                                                                            0.737469
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                           0.037167
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                                     -0.095360
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                                       0.018937
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                               0.141677
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                                     -0.142026
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                            0.234667
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                                       -0.170040
# LA_Population_young                                                                                                   -0.284244
# p_2014_3_all                                                                                                          -0.233119
# IMD_SCORE                                                                                                             -0.005946
# housing_benefit                                                                                                        0.031709
#
#                                                                                              White_Total  \
# unemployed_age_16_and_over                                                                      0.258579
# unemployment_age_16_to_24                                                                      -0.656651
# unemployment_age_25_to_34                                                                      -0.729376
# never_worked_age_16_and_over                                                                   -0.768886
# never_worked_age_16_to_24                                                                      -0.645328
# never_worked_age_25_to_34                                                                      -0.806876
# All_categories_Ethnic_group_of_HRP                                                              0.678118
# White_Total                                                                                     1.000000
# White_EnglishWelshScottishNorthern_IrishBritish                                                 0.949461
# White_Irish                                                                                    -0.631754
# White_Gypsy_or_Irish_Traveller                                                                 -0.016837
# White_Other_White                                                                              -0.440463
# Mixedmultiple_ethnic_group_Total                                                               -0.695092
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                           -0.707605
# Mixedmultiple_ethnic_group_White_and_Black_African                                             -0.619098
# Mixedmultiple_ethnic_group_White_and_Asian                                                     -0.641152
# Mixedmultiple_ethnic_group_Other_Mixed                                                         -0.580639
# AsianAsian_British_Total                                                                       -0.830662
# AsianAsian_British_Indian                                                                      -0.730370
# AsianAsian_British_Pakistani                                                                   -0.512685
# AsianAsian_British_Bangladeshi                                                                 -0.531407
# AsianAsian_British_Chinese                                                                     -0.364611
# AsianAsian_British_Other_Asian                                                                 -0.745926
# BlackAfricanCaribbeanBlack_British_Total                                                       -0.757803
# BlackAfricanCaribbeanBlack_British_African                                                     -0.731794
# BlackAfricanCaribbeanBlack_British_Caribbean                                                   -0.739788
# BlackAfricanCaribbeanBlack_British_Other_Black                                                 -0.712898
# Other_ethnic_group_Total                                                                       -0.643598
# Other_ethnic_group_Arab                                                                        -0.462018
# Other_ethnic_group_Any_other_ethnic_group                                                      -0.707863
# edu_highest                                                                                     0.596035
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                    0.249840
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value               0.354539
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                0.618730
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                        0.647226
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value               0.188431
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value    -0.164980
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                -0.738692
# LA_Population_young                                                                            -0.487941
# p_2014_3_all                                                                                   -0.537789
# IMD_SCORE                                                                                      -0.120519
# housing_benefit                                                                                -0.383188
#
#                                                                                              White_EnglishWelshScottishNorthern_IrishBritish  \
# unemployed_age_16_and_over                                                                                                          0.316526
# unemployment_age_16_to_24                                                                                                          -0.749411
# unemployment_age_25_to_34                                                                                                          -0.767217
# never_worked_age_16_and_over                                                                                                       -0.778426
# never_worked_age_16_to_24                                                                                                          -0.741209
# never_worked_age_25_to_34                                                                                                          -0.817804
# All_categories_Ethnic_group_of_HRP                                                                                                  0.468046
# White_Total                                                                                                                         0.949461
# White_EnglishWelshScottishNorthern_IrishBritish                                                                                     1.000000
# White_Irish                                                                                                                        -0.804297
# White_Gypsy_or_Irish_Traveller                                                                                                     -0.023947
# White_Other_White                                                                                                                  -0.699096
# Mixedmultiple_ethnic_group_Total                                                                                                   -0.845532
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                                               -0.738948
# Mixedmultiple_ethnic_group_White_and_Black_African                                                                                 -0.780987
# Mixedmultiple_ethnic_group_White_and_Asian                                                                                         -0.826665
# Mixedmultiple_ethnic_group_Other_Mixed                                                                                             -0.786499
# AsianAsian_British_Total                                                                                                           -0.834494
# AsianAsian_British_Indian                                                                                                          -0.667736
# AsianAsian_British_Pakistani                                                                                                       -0.434307
# AsianAsian_British_Bangladeshi                                                                                                     -0.610215
# AsianAsian_British_Chinese                                                                                                         -0.584327
# AsianAsian_British_Other_Asian                                                                                                     -0.867353
# BlackAfricanCaribbeanBlack_British_Total                                                                                           -0.823678
# BlackAfricanCaribbeanBlack_British_African                                                                                         -0.807884
# BlackAfricanCaribbeanBlack_British_Caribbean                                                                                       -0.791144
# BlackAfricanCaribbeanBlack_British_Other_Black                                                                                     -0.774186
# Other_ethnic_group_Total                                                                                                           -0.817164
# Other_ethnic_group_Arab                                                                                                            -0.654030
# Other_ethnic_group_Any_other_ethnic_group                                                                                          -0.850444
# edu_highest                                                                                                                         0.429432
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                                                        0.387123
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                                                   0.524891
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                                                    0.780651
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                                                            0.781963
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                                                   0.276568
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value                                        -0.367711
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                                                    -0.871561
# LA_Population_young                                                                                                                -0.417431
# p_2014_3_all                                                                                                                       -0.524952
# IMD_SCORE                                                                                                                          -0.076010
# ...
# BlackAfricanCaribbeanBlack_British_Caribbean                                                            0.392502
# BlackAfricanCaribbeanBlack_British_Other_Black                                                          0.400565
# Other_ethnic_group_Total                                                                                0.291116
# Other_ethnic_group_Arab                                                                                 0.246580
# Other_ethnic_group_Any_other_ethnic_group                                                               0.293239
# edu_highest                                                                                            -0.322639
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                            0.062094
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                      -0.146049
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                       -0.313448
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                               -0.285234
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                       0.132334
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value            -0.048648
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                         0.236289
# LA_Population_young                                                                                     1.000000
# p_2014_3_all                                                                                            0.782267
# IMD_SCORE                                                                                               0.165672
# housing_benefit                                                                                         0.383572
#
#                                                                                              p_2014_3_all  \
# unemployed_age_16_and_over                                                                      -0.002893
# unemployment_age_16_to_24                                                                        0.437877
# unemployment_age_25_to_34                                                                        0.519305
# never_worked_age_16_and_over                                                                     0.558363
# never_worked_age_16_to_24                                                                        0.407763
# never_worked_age_25_to_34                                                                        0.585929
# All_categories_Ethnic_group_of_HRP                                                              -0.233119
# White_Total                                                                                     -0.537789
# White_EnglishWelshScottishNorthern_IrishBritish                                                 -0.524952
# White_Irish                                                                                      0.480653
# White_Gypsy_or_Irish_Traveller                                                                  -0.089466
# White_Other_White                                                                                0.260001
# Mixedmultiple_ethnic_group_Total                                                                 0.492162
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                             0.586060
# Mixedmultiple_ethnic_group_White_and_Black_African                                               0.399286
# Mixedmultiple_ethnic_group_White_and_Asian                                                       0.412060
# Mixedmultiple_ethnic_group_Other_Mixed                                                           0.372463
# AsianAsian_British_Total                                                                         0.476159
# AsianAsian_British_Indian                                                                        0.269353
# AsianAsian_British_Pakistani                                                                     0.474272
# AsianAsian_British_Bangladeshi                                                                   0.552977
# AsianAsian_British_Chinese                                                                       0.274258
# AsianAsian_British_Other_Asian                                                                   0.433065
# BlackAfricanCaribbeanBlack_British_Total                                                         0.520900
# BlackAfricanCaribbeanBlack_British_African                                                       0.424890
# BlackAfricanCaribbeanBlack_British_Caribbean                                                     0.570922
# BlackAfricanCaribbeanBlack_British_Other_Black                                                   0.558200
# Other_ethnic_group_Total                                                                         0.409984
# Other_ethnic_group_Arab                                                                          0.352984
# Other_ethnic_group_Any_other_ethnic_group                                                        0.408873
# edu_highest                                                                                     -0.289550
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                    -0.054245
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value               -0.217629
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                -0.388034
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                        -0.420495
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value               -0.105189
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value      0.075896
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                  0.419082
# LA_Population_young                                                                              0.782267
# p_2014_3_all                                                                                     1.000000
# IMD_SCORE                                                                                        0.131796
# housing_benefit                                                                                  0.380799
#
#                                                                                              IMD_SCORE  \
# unemployed_age_16_and_over                                                                    0.346962
# unemployment_age_16_to_24                                                                     0.302631
# unemployment_age_25_to_34                                                                     0.423431
# never_worked_age_16_and_over                                                                  0.396905
# never_worked_age_16_to_24                                                                     0.197944
# never_worked_age_25_to_34                                                                     0.358432
# All_categories_Ethnic_group_of_HRP                                                           -0.005946
# White_Total                                                                                  -0.120519
# White_EnglishWelshScottishNorthern_IrishBritish                                              -0.076010
# White_Irish                                                                                   0.013631
# White_Gypsy_or_Irish_Traveller                                                               -0.127781
# White_Other_White                                                                            -0.057662
# Mixedmultiple_ethnic_group_Total                                                              0.096751
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                          0.199726
# Mixedmultiple_ethnic_group_White_and_Black_African                                            0.118745
# Mixedmultiple_ethnic_group_White_and_Asian                                                   -0.016520
# Mixedmultiple_ethnic_group_Other_Mixed                                                        0.036273
# AsianAsian_British_Total                                                                      0.175130
# AsianAsian_British_Indian                                                                     0.178759
# AsianAsian_British_Pakistani                                                                  0.198737
# AsianAsian_British_Bangladeshi                                                                0.176667
# AsianAsian_British_Chinese                                                                   -0.018667
# AsianAsian_British_Other_Asian                                                                0.020890
# BlackAfricanCaribbeanBlack_British_Total                                                      0.123953
# BlackAfricanCaribbeanBlack_British_African                                                    0.123964
# BlackAfricanCaribbeanBlack_British_Caribbean                                                  0.115064
# BlackAfricanCaribbeanBlack_British_Other_Black                                                0.121543
# Other_ethnic_group_Total                                                                      0.028063
# Other_ethnic_group_Arab                                                                       0.014141
# Other_ethnic_group_Any_other_ethnic_group                                                     0.035169
# edu_highest                                                                                  -0.173579
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                  0.456875
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value             0.234179
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value              0.025224
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                     -0.025799
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value            -0.001988
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value  -0.390583
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value               0.127348
# LA_Population_young                                                                           0.165672
# p_2014_3_all                                                                                  0.131796
# IMD_SCORE                                                                                     1.000000
# housing_benefit                                                                               0.566173
#
#                                                                                              housing_benefit
# unemployed_age_16_and_over                                                                          0.311330
# unemployment_age_16_to_24                                                                           0.644214
# unemployment_age_25_to_34                                                                           0.796308
# never_worked_age_16_and_over                                                                        0.720347
# never_worked_age_16_to_24                                                                           0.541049
# never_worked_age_25_to_34                                                                           0.707142
# All_categories_Ethnic_group_of_HRP                                                                  0.031709
# White_Total                                                                                        -0.383188
# White_EnglishWelshScottishNorthern_IrishBritish                                                    -0.428157
# White_Irish                                                                                         0.405399
# White_Gypsy_or_Irish_Traveller                                                                     -0.131413
# White_Other_White                                                                                   0.349044
# Mixedmultiple_ethnic_group_Total                                                                    0.557339
# Mixedmultiple_ethnic_group_White_and_Black_Caribbean                                                0.607571
# Mixedmultiple_ethnic_group_White_and_Black_African                                                  0.555168
# Mixedmultiple_ethnic_group_White_and_Asian                                                          0.396457
# Mixedmultiple_ethnic_group_Other_Mixed                                                              0.481843
# AsianAsian_British_Total                                                                            0.353387
# AsianAsian_British_Indian                                                                           0.210744
# AsianAsian_British_Pakistani                                                                        0.290001
# AsianAsian_British_Bangladeshi                                                                      0.418306
# AsianAsian_British_Chinese                                                                          0.244579
# AsianAsian_British_Other_Asian                                                                      0.353417
# BlackAfricanCaribbeanBlack_British_Total                                                            0.558190
# BlackAfricanCaribbeanBlack_British_African                                                          0.549053
# BlackAfricanCaribbeanBlack_British_Caribbean                                                        0.535615
# BlackAfricanCaribbeanBlack_British_Other_Black                                                      0.520814
# Other_ethnic_group_Total                                                                            0.434235
# Other_ethnic_group_Arab                                                                             0.322655
# Other_ethnic_group_Any_other_ethnic_group                                                           0.469760
# edu_highest                                                                                        -0.272519
# _All_persons_Highest_Level_of_Qualification_No_qualifications_measures_Value                        0.354286
# _All_persons_Highest_Level_of_Qualification_Level_1_qualifications_measures_Value                   0.041339
# All_persons_Highest_Level_of_Qualification_Level_2_qualifications_measures_Value                   -0.286905
# All_persons_Highest_Level_of_Qualification_Apprenticeship_measures_Value                           -0.381837
# _All_persons_Highest_Level_of_Qualification_Level_3_qualifications_measures_Value                  -0.231462
# _All_persons_Highest_Level_of_Qualification_Level_4_qualifications_and_above_measures_Value        -0.243771
# _All_persons_Highest_Level_of_Qualification_Other_qualifications_measures_Value                     0.523009
# LA_Population_young                                                                                 0.383572
# p_2014_3_all                                                                                        0.380799
# IMD_SCORE                                                                                           0.566173
# housing_benefit                                                                                     1.000000

# %% [markdown]
# Specifically, let's see correlation with the target variable:

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (14, 14)
correlation_with_target = train_filled[predictors + [target_colname]].corr()[target_colname].order()
correlation_with_target[ np.abs(correlation_with_target) > 0.05][:-1].plot(kind='barh', title='Correlations with target (only corr >= 0.05 included)')

# %% [markdown]
# ### Individual relationships

# %%
from sklearn import linear_model
clf_ind = linear_model.LinearRegression()
plt.rcParams['figure.figsize'] = (10, 8)

# %% [markdown]
# #### Young population

# %%
plt.rcParams['figure.figsize'] = (15, 8)

predictor = population_colname
clf_ind.fit(train_filled[[predictor]], train_filled[target_colname])
prediction = clf_ind.predict(train_filled[[predictor]])

fig = plt.figure()
ax = fig.add_subplot(121)
ax.scatter(train_filled[predictor], train_filled[target_colname])
ax.plot(train_filled[predictor], prediction, color='darkorange', lw=2)

mask = train_filled['Presented_Normalised'] > 0.01
clf_ind.fit(train_filled[mask][[predictor]], train_filled[mask][target_colname])
prediction = clf_ind.predict(train_filled[mask][[predictor]])
ax2 = fig.add_subplot(122)
ax2.scatter(train_filled[mask][predictor], train_filled[mask][target_colname])
ax2.plot(train_filled[mask][predictor], prediction, color='darkorange', lw=2)

# %%
train_filled['p2014_normalised'] = train_filled['p_2014_3_all']/train_filled[population_colname]
predictor = 'p2014_normalised'

clf_ind.fit(train_filled[[predictor]], train_filled[target_colname])
prediction = clf_ind.predict(train_filled[[predictor]])

fig = plt.figure()
ax = fig.add_subplot(121)
ax.scatter(train_filled[predictor], train_filled[target_colname])
ax.plot(train_filled[predictor], prediction, color='darkorange', lw=2)

mask = train_filled['Presented_Normalised'] > 0.01
clf_ind.fit(train_filled[mask][[predictor]], train_filled[mask][target_colname])
prediction = clf_ind.predict(train_filled[mask][[predictor]])
ax2 = fig.add_subplot(122)
ax2.scatter(train_filled[mask][predictor], train_filled[mask][target_colname])
ax2.plot(train_filled[mask][predictor], prediction, color='darkorange', lw=2)
# Out:
# /home/adam/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
plt.rcParams['figure.figsize'] = (15, 8)

predictor = 'IMD_SCORE'
target_colname = 'Presented_Normalised'
clf_ind.fit(train_filled[[predictor]], train_filled[target_colname])
prediction = clf_ind.predict(train_filled[[predictor]])

fig = plt.figure()
ax = fig.add_subplot(121)
ax.scatter(train_filled[predictor], train_filled[target_colname])
ax.plot(train_filled[predictor], prediction, color='darkorange', lw=2)

mask = train_filled['Presented_Normalised'] > 0.01
clf_ind.fit(train_filled[mask][[predictor]], train_filled[mask][target_colname])
prediction = clf_ind.predict(train_filled[mask][[predictor]])
ax2 = fig.add_subplot(122)
ax2.scatter(train_filled[mask][predictor], train_filled[mask][target_colname])
ax2.plot(train_filled[mask][predictor], prediction, color='darkorange', lw=2)

# %%
predictor = 'unemployment_age_25_to_34'
clf_ind.fit(train_filled[[predictor]], train_filled[target_colname])
prediction = clf_ind.predict(train_filled[[predictor]])

fig = plt.figure()
ax = fig.add_subplot(121)
ax.scatter(train_filled[predictor], train_filled[target_colname])
ax.plot(train_filled[predictor], prediction, color='darkorange', lw=2)

mask = train_filled['Presented_Normalised'] > 0.01
clf_ind.fit(train_filled[mask][[predictor]], train_filled[mask][target_colname])
prediction = clf_ind.predict(train_filled[mask][[predictor]])
ax2 = fig.add_subplot(122)
ax2.scatter(train_filled[mask][predictor], train_filled[mask][target_colname])
ax2.plot(train_filled[mask][predictor], prediction, color='darkorange', lw=2)

# %%
predictor = 'BlackAfricanCaribbeanBlack_British_African'
clf_ind.fit(train_filled[[predictor]], train_filled[target_colname])
prediction = clf_ind.predict(train_filled[[predictor]])

fig = plt.figure()
ax = fig.add_subplot(121)
ax.scatter(train_filled[predictor], train_filled[target_colname])
ax.plot(train_filled[predictor], prediction, color='darkorange', lw=2)

mask = train_filled['Presented_Normalised'] > 0.01
clf_ind.fit(train_filled[mask][[predictor]], train_filled[mask][target_colname])
prediction = clf_ind.predict(train_filled[mask][[predictor]])
ax2 = fig.add_subplot(122)
ax2.scatter(train_filled[mask][predictor], train_filled[mask][target_colname])
ax2.plot(train_filled[mask][predictor], prediction, color='darkorange', lw=2)

# %%
predictor = 'edu_highest'
clf_ind.fit(train_filled[[predictor]], train_filled[target_colname])
prediction = clf_ind.predict(train_filled[[predictor]])

fig = plt.figure()
ax = fig.add_subplot(121)
ax.scatter(train_filled[predictor], train_filled[target_colname])
ax.plot(train_filled[predictor], prediction, color='darkorange', lw=2)

mask = train_filled['Presented_Normalised'] > 0.01
clf_ind.fit(train_filled[mask][[predictor]], train_filled[mask][target_colname])
prediction = clf_ind.predict(train_filled[mask][[predictor]])
ax2 = fig.add_subplot(122)
ax2.scatter(train_filled[mask][predictor], train_filled[mask][target_colname])
ax2.plot(train_filled[mask][predictor], prediction, color='darkorange', lw=2)

# %% [markdown]
# ### Linear Model
#
# #### All data

# %%
picked_predictors = [population_colname, 'housing_benefit', 'p_2014_3_all', 'BlackAfricanCaribbeanBlack_British_African', 'unemployment_age_25_to_34', 'edu_highest', 'White_Total', 'IMD_SCORE']

# %%
import statsmodels.formula.api as sm
model1 = sm.ols(formula="{0} ~ {1}".format(TARGET_COLNAME, ' + '.join(picked_predictors)), data=train_filled).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     TOTAL_Presented_Young_ppl_2014   R-squared:                       0.450
# Model:                                        OLS   Adj. R-squared:                  0.415
# Method:                             Least Squares   F-statistic:                     12.69
# Date:                            Wed, 12 Aug 2015   Prob (F-statistic):           3.32e-13
# Time:                                    21:37:44   Log-Likelihood:                -934.09
# No. Observations:                             133   AIC:                             1886.
# Df Residuals:                                 124   BIC:                             1912.
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                    302.3751   1200.030      0.252      0.801     -2072.820  2677.570
# LA_Population_young                            0.0147      0.002      7.016      0.000         0.011     0.019
# housing_benefit                             1373.7948   2407.934      0.571      0.569     -3392.181  6139.771
# p_2014_3_all                                  -1.3901      0.498     -2.794      0.006        -2.375    -0.405
# BlackAfricanCaribbeanBlack_British_African  2715.4506   5889.329      0.461      0.646     -8941.181  1.44e+04
# unemployment_age_25_to_34                   5315.1836   6981.843      0.761      0.448     -8503.840  1.91e+04
# edu_highest                                 -880.1513   1774.738     -0.496      0.621     -4392.856  2632.553
# White_Total                                  707.4448   1304.629      0.542      0.589     -1874.782  3289.671
# IMD_SCORE                                     -3.0656      2.355     -1.302      0.195        -7.726     1.595
# ==============================================================================
# Omnibus:                       62.591   Durbin-Watson:                   1.639
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              227.102
# Skew:                           1.734   Prob(JB):                     4.85e-50
# Kurtosis:                       8.381   Cond. No.                     8.60e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.6e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### "Reliable" data
#
# (take only those authorities for which the franction of presented is > 0.01)

# %%
mask = train_filled['Presented_Normalised'] > 0.01
import statsmodels.formula.api as sm
model2 = sm.ols(formula="{0} ~ {1}".format(TARGET_COLNAME, ' + '.join(picked_predictors)), data=train_filled[mask]).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     TOTAL_Presented_Young_ppl_2014   R-squared:                       0.643
# Model:                                        OLS   Adj. R-squared:                  0.582
# Method:                             Least Squares   F-statistic:                     10.56
# Date:                            Wed, 12 Aug 2015   Prob (F-statistic):           2.49e-08
# Time:                                    21:39:13   Log-Likelihood:                -391.90
# No. Observations:                              56   AIC:                             801.8
# Df Residuals:                                  47   BIC:                             820.0
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                   1282.0635   1780.302      0.720      0.475     -2299.442  4863.569
# LA_Population_young                            0.0204      0.003      7.418      0.000         0.015     0.026
# housing_benefit                            -1372.2698   3431.368     -0.400      0.691     -8275.293  5530.753
# p_2014_3_all                                  -1.0552      1.284     -0.822      0.415        -3.638     1.527
# BlackAfricanCaribbeanBlack_British_African  -703.1126   6996.901     -0.100      0.920     -1.48e+04  1.34e+04
# unemployment_age_25_to_34                   8674.0751   9992.706      0.868      0.390     -1.14e+04  2.88e+04
# edu_highest                                -2029.4012   2753.972     -0.737      0.465     -7569.677  3510.875
# White_Total                                 1136.6336   2018.885      0.563      0.576     -2924.839  5198.107
# IMD_SCORE                                     -2.6146      3.684     -0.710      0.481       -10.025     4.796
# ==============================================================================
# Omnibus:                       38.181   Durbin-Watson:                   1.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.133
# Skew:                           1.985   Prob(JB):                     3.30e-24
# Kurtosis:                       8.530   Cond. No.                     7.29e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Conclusion
#
# As you can see from the plots, none of the variables that I've tried are really correlated, and I tried the most _correlated_ ones...
